# %%
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
pd.set_option("display.max_columns", None)

# %%
stats = pd.read_csv("/home/anuroopa/Desktop/Data_analysis_projects/Pokemon/stats.csv", index_col = 0)
type_chart = pd.read_csv("/home/anuroopa/Desktop/Data_analysis_projects/Pokemon/Pokemon_Type_Chart.csv", index_col = 0)
details = pd.read_csv("/home/anuroopa/Desktop/Data_analysis_projects/Pokemon/data.csv", index_col = 0)
results = pd.read_csv("/home/anuroopa/Desktop/Data_analysis_projects/Pokemon/result.csv", index_col = 0)
details = details.merge(stats)
details = details.merge(results)

# %%
details["legendary"] = np.where(details["legendary"] == "Yes", 1, 0)
details["number"] = details["number"].str.replace("#0", "")
details[["type1", "type2"]] = details["type"].str.split(" / ", expand = True).fillna("Nil")

# %%
details.head()
# Out:
#   number        name            type                 ability hidden_ability  \
# 0    001   Bulbasaur  Grass / Poison                Overgrow    Chlorophyll
# 1    002     Ivysaur  Grass / Poison                Overgrow    Chlorophyll
# 2    003    Venusaur  Grass / Poison  Overgrow / Chlorophyll      Thick Fat
# 3    004  Charmander            Fire                   Blaze    Solar Power
# 4    005  Charmeleon            Fire                   Blaze    Solar Power
#
#                gender_ratio hatch_cycle         egg_group  \
# 0  87.5% male, 12.5% female    20cycles   Monster / Grass
# 1  87.5% male, 12.5% female    20cycles   Monster / Grass
# 2  87.5% male, 12.5% female    20cycles   Monster / Grass
# 3  87.5% male, 12.5% female    20cycles  Monster / Dragon
# 4  87.5% male, 12.5% female    20cycles  Monster / Dragon
#
#    Base_Experience_Yield  height  weight leveling_rate  color  \
# 0                   64.0     0.7     6.9   Medium Slow  Green
# 1                  142.0     1.0    13.0   Medium Slow  Green
# 2                  236.0     2.0   100.0   Medium Slow  Green
# 3                   62.0     0.6     8.5   Medium Slow    Red
# 4                  142.0     1.1    19.0   Medium Slow    Red
#
#    base_friendship        category  gen legendary    hp  attack  defense  \
# 0             70.0    Seed Pokémon    1        No  45.0    49.0     49.0
# 1             70.0    Seed Pokémon    1        No  60.0    62.0     63.0
# 2             70.0    Seed Pokémon    1        No  80.0    82.0     83.0
# 3             70.0  Lizard Pokémon    1        No  39.0    52.0     43.0
# 4             70.0   Flame Pokémon    1        No  58.0    64.0     58.0
#
#    special_attack  special_defense  speed  total  win  lose  type1   type2
# 0            65.0             65.0   45.0  318.0  270   755  Grass  Poison
# 1            80.0             80.0   60.0  405.0  437   588  Grass  Poison
# 2           100.0            100.0   80.0  525.0  658   367  Grass  Poison
# 3            60.0             50.0   65.0  309.0  200   825   Fire     Nil
# 4            80.0             65.0   80.0  405.0  394   631   Fire     Nil

# %%
if details["number"].iloc[0].startswith("#0"):
    print(True)

# %%
details.describe()
# Out:
#        Base_Experience_Yield       height       weight  base_friendship  \
# count            1025.000000  1025.000000  1025.000000      1025.000000
# mean              151.089756     1.211317    66.977463        59.897561
# std                79.022246     1.248299   121.277522        22.482942
# min                36.000000     0.100000     0.100000         0.000000
# 25%                66.000000     0.500000     8.500000        50.000000
# 50%               158.000000     1.000000    28.000000        70.000000
# 75%               184.000000     1.500000    70.000000        70.000000
# max               635.000000    20.000000   999.900000       140.000000
#
#                gen           hp       attack      defense  special_attack  \
# count  1025.000000  1025.000000  1025.000000  1025.000000     1025.000000
# mean      4.741463    70.072195    77.380488    72.395122       69.959024
# std       2.633633    26.665218    29.723557    29.364210       29.637133
# min       1.000000     1.000000     5.000000     5.000000       10.000000
# 25%       3.000000    50.000000    55.000000    50.000000       47.000000
# 50%       5.000000    67.000000    75.000000    70.000000       65.000000
# 75%       7.000000    85.000000   100.000000    90.000000       90.000000
# max       9.000000   255.000000   181.000000   230.000000      173.000000
#
#        special_defense        speed        total          win         lose
# count      1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean         70.088780    67.127805   427.023415   481.060488   543.939512
# std          26.668189    28.654567   112.779018   240.703239   240.703239
# min          20.000000     5.000000   175.000000    11.000000    54.000000
# 25%          50.000000    45.000000   325.000000   267.000000   347.000000
# 50%          65.000000    65.000000   450.000000   509.000000   516.000000
# 75%          85.000000    88.000000   505.000000   678.000000   758.000000
# max         230.000000   200.000000   720.000000   971.000000  1014.000000

# %%
details["type1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
def get_type_wise_result(details):
    types = ['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
             'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
             'Dragon', 'Dark', 'Steel', 'Flying']

    result = []
    for i, type_ in enumerate(types):
        data = details[details["type"].str.contains(type_, case = False) == True]
        count = len(data)
        total = count * 1025
        wins = data["win"].sum()
        loses = data["lose"].sum()
        pct_wins = wins/total * 100
        pct_loses = loses/total * 100
        result.append({"type": type_, "number": count,"wins": wins, "loses": loses, 
                       "pct_wins": pct_wins, "pct_loses": pct_loses})
        
    return pd.DataFrame(result)

# %%
type_result = get_type_wise_result(details)
type_result = type_result.sort_values("pct_wins", ascending = False)
type_result.index = range(0, len(type_result))
type_result
# Out:
#         type  number   wins  loses   pct_wins  pct_loses
# 0     Dragon      70  45685  26065  63.672474  36.327526
# 1      Steel      65  41434  25191  62.189869  37.810131
# 2   Fighting      73  42830  31995  57.240227  42.759773
# 3       Dark      69  39589  31136  55.975963  44.024037
# 4      Ghost      65  36439  30186  54.692683  45.307317
# 5        Ice      48  26431  22769  53.721545  46.278455
# 6       Rock      74  39840  36010  52.524720  47.475280
# 7    Psychic     102  54469  50081  52.098517  47.901483
# 8   Electric      69  36750  33975  51.961824  48.038176
# 9     Ground      75  39776  37099  51.741138  48.258862
# 10    Flying     109  57807  53918  51.740434  48.259566
# 11      Fire      81  42688  40337  51.415839  48.584161
# 12     Fairy      64  32128  33472  48.975610  51.024390
# 13    Poison      83  38573  46502  45.339994  54.660006
# 14     Water     154  70613  87237  44.734241  55.265759
# 15     Grass     127  54644  75531  41.977338  58.022662
# 16    Normal     131  52975  81300  39.452616  60.547384
# 17       Bug      92  36061  58239  38.240721  61.759279

# %%
#details.nlargest(50, "win")

# %%
details["hp"].corr(details["win"])
# Out:
# np.float64(0.6565113686138544)

# %%
plt.figure(dpi = 120)
plt.barh(type_result["type"], type_result["pct_wins"],
        color="b", label="Wins")
plt.barh(type_result["type"], type_result["pct_loses"],
         left=type_result["pct_wins"], color="r", label="Loses")
plt.xlabel("Percentage", fontweight="bold")
plt.legend()
plt.title("Percentage of wins and loses according to type", fontweight = "bold")
plt.show()

# %%
plt.figure(dpi = 120)
top_20_wins = details.nlargest(20, "win")
plt.barh(top_20_wins["name"], top_20_wins["win"], color = "b")
plt.show()

# %%
plt.figure(dpi = 120)
top_20_loses = details.nlargest(20, "lose")
plt.barh(top_20_loses["name"], top_20_loses["lose"], color = "r")
plt.show()

# %%
details[details["type"].str.contains("Fire") == True]["win"].sum()
# Out:
# np.int64(42688)

# %%
print(len(details[details["win"] < 512]))
print(len(details[details["win"] >= 512]))
# Out:
# 520
# 505

# %%
details["legendary"] = np.where(details["legendary"] == "Yes", 1, 0)

# %%
needs = ['Base_Experience_Yield', 'height', 'weight',
        'base_friendship', 'gen',
       'legendary', 'hp', 'attack', 'defense', 'special_attack',
       'special_defense', 'speed', 'total', 'win', 'lose']

# %%
details[needs].corr()
# Out:
#                        Base_Experience_Yield    height    weight  \
# Base_Experience_Yield               1.000000  0.476226  0.433907
# height                              0.476226  1.000000  0.632504
# weight                              0.433907  0.632504  1.000000
# base_friendship                    -0.335197 -0.313313 -0.383344
# gen                                 0.170967  0.052696  0.111277
# legendary                           0.465757  0.233596  0.291249
# hp                                  0.683652  0.483217  0.476355
# attack                              0.620316  0.384335  0.402339
# defense                             0.549325  0.348725  0.447561
# special_attack                      0.643602  0.319507  0.185233
# special_defense                     0.654099  0.276189  0.265010
# speed                               0.513936  0.201393  0.043313
# total                               0.922539  0.506783  0.457546
# win                                 0.878068  0.488327  0.448926
# lose                               -0.878068 -0.488327 -0.448926
#
#                        base_friendship       gen  legendary        hp  \
# Base_Experience_Yield        -0.335197  0.170967   0.465757  0.683652
# height                       -0.313313  0.052696   0.233596  0.483217
# weight                       -0.383344  0.111277   0.291249  0.476355
# base_friendship               1.000000 -0.407735  -0.327514 -0.174503
# gen                          -0.407735  1.000000   0.087991  0.121887
# legendary                    -0.327514  0.087991   1.000000  0.275212
# hp                           -0.174503  0.121887   0.275212  1.000000
# attack                       -0.307630  0.146967   0.276330  0.480018
# defense                      -0.228202  0.099932   0.271141  0.299119
# special_attack               -0.243125  0.086569   0.352789  0.356717
# special_defense              -0.163128  0.065650   0.346021  0.365108
# speed                        -0.230114  0.079556   0.308195  0.179567
# total                        -0.342685  0.152059   0.461332  0.666531
# win                          -0.328558  0.189822   0.382629  0.656511
# lose                          0.328558 -0.189822  -0.382629 -0.656511
#
#                          attack   defense  special_attack  special_defense  \
# Base_Experience_Yield  0.620316  0.549325        0.643602         0.654099
# height                 0.384335  0.348725        0.319507         0.276189
# weight                 0.402339  0.447561        0.185233         0.265010
# base_friendship       -0.307630 -0.228202       -0.243125        -0.163128
# gen                    0.146967  0.099932        0.086569         0.065650
# legendary              0.276330  0.271141        0.352789         0.346021
# hp                     0.480018  0.299119        0.356717         0.365108
# attack                 1.000000  0.466646        0.286626         0.226016
# defense                0.466646  1.000000        0.208710         0.501515
# special_attack         0.286626  0.208710        1.000000         0.492095
# special_defense        0.226016  0.501515        0.492095         1.000000
# speed                  0.353644  0.007538        0.423616         0.213162
# total                  0.717170  0.629432        0.701008         0.696413
# win                    0.725566  0.642266        0.652093         0.628139
# lose                  -0.725566 -0.642266       -0.652093        -0.628139
#
#                           speed     total       win      lose
# Base_Experience_Yield  0.513936  0.922539  0.878068 -0.878068
# height                 0.201393  0.506783  0.488327 -0.488327
# weight                 0.043313  0.457546  0.448926 -0.448926
# base_friendship       -0.230114 -0.342685 -0.328558  0.328558
# gen                    0.079556  0.152059  0.189822 -0.189822
# legendary              0.308195  0.461332  0.382629 -0.382629
# hp                     0.179567  0.666531  0.656511 -0.656511
# attack                 0.353644  0.717170  0.725566 -0.725566
# defense                0.007538  0.629432  0.642266 -0.642266
# special_attack         0.423616  0.701008  0.652093 -0.652093
# special_defense        0.213162  0.696413  0.628139 -0.628139
# speed                  1.000000  0.553428  0.483904 -0.483904
# total                  0.553428  1.000000  0.956522 -0.956522
# win                    0.483904  0.956522  1.000000 -1.000000
# lose                  -0.483904 -0.956522 -1.000000  1.000000

# %%
plt.figure(dpi = 120)
sns.scatterplot(y = details["Base_Experience_Yield"], x = details["win"],
               hue = details["legendary"])
plt.show()

# %%
plt.figure(dpi = 120)
ax = sns.scatterplot(y = details["total"], x = details["win"],
               hue = details["legendary"])
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=["No", "Yes"])
plt.xlabel("Wins", fontweight = "bold")
plt.ylabel("Base Stat Total", fontweight = "bold")
plt.title("Relationship Between Base Stat Total and Wins", fontweight = "bold")
print(details["total"].corr(details["win"]))
plt.show()
# Out:
# 0.9565219359201655

# %%
plt.figure(dpi = 120)
ax = sns.scatterplot(y = details["total"], x = details["lose"],
               hue = details["legendary"])
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=["No", "Yes"])
plt.xlabel("Loses", fontweight = "bold")
plt.ylabel("Base Stat Total", fontweight = "bold")
plt.title("Relationship Between Base Stat Total and Loses", fontweight = "bold")
print(details["total"].corr(details["lose"]))
plt.show()
# Out:
# -0.9565219359201655

# %%
ultra_beast = details[details["ability"].str.contains("Beast Boost") == True].nlargest(11, "win")
print(len(ultra_beast))
# Out:
# 11

# %%
paradox = details[details["category"].str.contains("Paradox Pokémon") == True].nlargest(22, "win")
print(len(paradox))
# Out:
# 22

# %%
plt.figure(dpi = 120)
plt.barh(ultra_beast["name"], ultra_beast["win"], color="b",
        label="Wins")
plt.barh(ultra_beast["name"], ultra_beast["lose"], color="r", left = ultra_beast["win"],
        label="Loses")
plt.title("Win-Lose Ratio of Ultra Beasts", fontweight = "bold")
plt.xlabel("Win-Lose")
plt.legend()
plt.show()

# %%
plt.figure(dpi = 120)
plt.barh(paradox["name"], paradox["win"], color="b",
        label="Wins")
plt.barh(paradox["name"], paradox["lose"], color="r", left = paradox["win"],
        label="Loses")
plt.title("Win-Lose Ratio of Paradox Pokemon", fontweight = "bold")
plt.xlabel("Win-Lose")
plt.legend()
plt.show()

# %%
starters = ["Bulbasaur","Charmander","Squirtle","Chikorita",
            "Cyndaquil","Totodile","Treecko","Torchic","Mudkip",
            "Turtwig","Chimchar","Piplup","Snivy","Tepig","Oshawott",
            "Chespin","Fennekin", "Froakie","Rowlet","Litten",
            "Popplio", "Grookey","Scorbunny","Sobble",
            "Sprigatito","Fuecoco", "Quaxly"]

# %%
def get_starter_data(starters, details):
    for i, name in enumerate(starters):
        if ((details["name"].str.contains(name)).sum() == 1) & (i < 1):
            num = int(details[details["name"] == name]["number"].iloc[0]) - 1
            data = details.loc[[num, num+1, num+2], :]
            data_final = details.loc[[num+2], :]
            starter_data = data
            starter_final = data_final
        elif ((details["name"].str.contains(name)).sum() == 1) & (i >= 1):
            num = int(details[details["name"] == name]["number"].iloc[0]) - 1
            data = details.loc[[num, num+1, num+2], :]
            data_final = details.loc[[num+2], :]
            starter_data = pd.concat([starter_data, data])
            starter_final = pd.concat([starter_final, data_final])
    return starter_data, starter_final

# %%
starter_data, starter_final = get_starter_data(starters, details)

# %%
starter_data.index = range(0, len(starter_data))

(starter_final.nlargest(27, "win")[["name", "win"]])
starter_data["stage"] = (starter_data.index % 3) + 1
# starter_data.loc[np.array(starter_data.index)[np.arange(0,81,3)], "stage"] = 1
# starter_data.loc[np.array(starter_data.index)[np.arange(1,81,3)], "stage"] = 2
# starter_data.loc[np.array(starter_data.index)[np.arange(2,81,3)], "stage"] = 3

# %%
starter_data
# Out:
#    number        name              type                 ability  \
# 0     001   Bulbasaur    Grass / Poison                Overgrow
# 1     002     Ivysaur    Grass / Poison                Overgrow
# 2     003    Venusaur    Grass / Poison  Overgrow / Chlorophyll
# 3     004  Charmander              Fire                   Blaze
# 4     005  Charmeleon              Fire                   Blaze
# ..    ...         ...               ...                     ...
# 76    910    Crocalor              Fire                   Blaze
# 77    911  Skeledirge      Fire / Ghost                   Blaze
# 78    912      Quaxly             Water                 Torrent
# 79    913    Quaxwell             Water                 Torrent
# 80    914   Quaquaval  Water / Fighting                 Torrent
#
#    hidden_ability              gender_ratio hatch_cycle         egg_group  \
# 0     Chlorophyll  87.5% male, 12.5% female    20cycles   Monster / Grass
# 1     Chlorophyll  87.5% male, 12.5% female    20cycles   Monster / Grass
# 2       Thick Fat  87.5% male, 12.5% female    20cycles   Monster / Grass
# 3     Solar Power  87.5% male, 12.5% female    20cycles  Monster / Dragon
# 4     Solar Power  87.5% male, 12.5% female    20cycles  Monster / Dragon
# ..            ...                       ...         ...               ...
# 76        Unaware  87.5% male, 12.5% female    20cycles             Field
# 77        Unaware  87.5% male, 12.5% female    20cycles             Field
# 78          Moxie  87.5% male, 12.5% female    20cycles  Flying / Water 1
# 79          Moxie  87.5% male, 12.5% female    20cycles  Flying / Water 1
# 80          Moxie  87.5% male, 12.5% female    20cycles  Flying / Water 1
#
#     Base_Experience_Yield  height  weight leveling_rate  color  \
# 0                    64.0     0.7     6.9   Medium Slow  Green
# 1                   142.0     1.0    13.0   Medium Slow  Green
# 2                   236.0     2.0   100.0   Medium Slow  Green
# 3                    62.0     0.6     8.5   Medium Slow    Red
# 4                   142.0     1.1    19.0   Medium Slow    Red
# ..                    ...     ...     ...           ...    ...
# 76                  144.0     1.0    30.7   Medium Slow    Red
# 77                  265.0     1.6   326.5   Medium Slow    Red
# 78                   62.0     0.5     6.1   Medium Slow   Blue
# 79                  144.0     1.2    21.5   Medium Slow   Blue
# 80                  265.0     1.8    61.9   Medium Slow   Blue
#
#     base_friendship            category  gen  legendary     hp  attack  \
# 0              70.0        Seed Pokémon    1          0   45.0    49.0
# 1              70.0        Seed Pokémon    1          0   60.0    62.0
# 2              70.0        Seed Pokémon    1          0   80.0    82.0
# 3              70.0      Lizard Pokémon    1          0   39.0    52.0
# 4              70.0       Flame Pokémon    1          0   58.0    64.0
# ..              ...                 ...  ...        ...    ...     ...
# 76             50.0   Fire Croc Pokémon    9          0   81.0    55.0
# 77             50.0      Singer Pokémon    9          0  104.0    75.0
# 78             50.0    Duckling Pokémon    9          0   55.0    65.0
# 79             50.0  Practicing Pokémon    9          0   70.0    85.0
# 80             50.0      Dancer Pokémon    9          0   85.0   120.0
#
#     defense  special_attack  special_defense  speed  total  win  lose  type1  \
# 0      49.0            65.0             65.0   45.0  318.0  270   755  Grass
# 1      63.0            80.0             80.0   60.0  405.0  437   588  Grass
# 2      83.0           100.0            100.0   80.0  525.0  658   367  Grass
# 3      43.0            60.0             50.0   65.0  309.0  200   825   Fire
# 4      58.0            80.0             65.0   80.0  405.0  394   631   Fire
# ..      ...             ...              ...    ...    ...  ...   ...    ...
# 76     78.0            90.0             58.0   49.0  411.0  490   535   Fire
# 77    100.0           110.0             75.0   66.0  530.0  813   212   Fire
# 78     45.0            50.0             45.0   50.0  310.0  189   836  Water
# 79     65.0            65.0             60.0   65.0  410.0  400   625  Water
# 80     80.0            85.0             75.0   85.0  530.0  734   291  Water
#
#        type2  stage
# 0     Poison      1
# 1     Poison      2
# 2     Poison      3
# 3        Nil      1
# 4        Nil      2
# ..       ...    ...
# 76       Nil      2
# 77     Ghost      3
# 78       Nil      1
# 79       Nil      2
# 80  Fighting      3
#
# [81 rows x 29 columns]

# %%
plt.figure(dpi = 120)
x = starter_data[starter_data["stage"] == 1]["name"]
y = starter_data[starter_data["stage"] == 1]["win"]
z = starter_data[starter_data["stage"] == 1]["lose"]
plt.subplot(1,2,1)
plt.barh(x, y)
plt.show()

# %%
num = int(details[details["name"] == "Froakie"]["number"].iloc[0]) - 1
details.loc[[num, num+1, num+2], :]
# Out:
#     number       name          type  ability hidden_ability  \
# 655    656    Froakie         Water  Torrent        Protean
# 656    657  Frogadier         Water  Torrent        Protean
# 657    658   Greninja  Water / Dark  Torrent        Protean
#
#                  gender_ratio hatch_cycle egg_group  Base_Experience_Yield  \
# 655  87.5% male, 12.5% female    20cycles   Water 1                   63.0
# 656  87.5% male, 12.5% female    20cycles   Water 1                  142.0
# 657  87.5% male, 12.5% female    20cycles   Water 1                  239.0
#
#      height  weight leveling_rate color  base_friendship             category  \
# 655     0.3     7.0   Medium Slow  Blue             70.0  Bubble Frog Pokémon
# 656     0.6    10.9   Medium Slow  Blue             70.0  Bubble Frog Pokémon
# 657     1.5    40.0   Medium Slow  Blue             70.0        Ninja Pokémon
#
#      gen legendary    hp  attack  defense  special_attack  special_defense  \
# 655    6        No  41.0    56.0     40.0            62.0             44.0
# 656    6        No  54.0    63.0     52.0            83.0             56.0
# 657    6        No  72.0    95.0     67.0           103.0             71.0
#
#      speed  total  win  lose  type1 type2
# 655   71.0  314.0  185   840  Water   Nil
# 656   97.0  405.0  358   667  Water   Nil
# 657  122.0  530.0  687   338  Water  Dark

# %%
num
# Out:
# Index([655], dtype='int64')

# %%
(details["name"].str.contains("Froakie")).sum()
# Out:
# np.int64(1)

# %%
np.array(range(0,81))[np.arange(0, 81, 3)]
# Out:
# array([ 0,  3,  6,  9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48,
#        51, 54, 57, 60, 63, 66, 69, 72, 75, 78])
